# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import os
import warnings
warnings.filterwarnings('ignore')

# %%
for _,dirnames, filenames in os.walk('C:\\Users\\ajaym\\Desktop\\credit_score_classification'):
    for filename in filenames:
        print(filename)
# Out:
# Credit-Score-Data.zip
# EDA-checkpoint.ipynb
# EDA.ipynb
# train.csv
# EDA-checkpoint.ipynb

# %%
pd.set_option('display.max_columns', 100)

# %%
raw_data = pd.read_csv('train.csv')

raw_data.head()
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
# 3  5637         3392      4  Aaron Maashoh  23.0  821000265.0  Scientist
# 4  5638         3392      5  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
# 3       19114.12            1824.843333                3.0              4.0
# 4       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# ...

# %%
mydf = raw_data.copy()


mydf.head(3)
# Out:
#      ID  Customer_ID  Month           Name   Age          SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh  23.0  821000265.0  Scientist
# 1  5635         3392      2  Aaron Maashoh  23.0  821000265.0  Scientist
# 2  5636         3392      3  Aaron Maashoh  23.0  821000265.0  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0       19114.12            1824.843333                3.0              4.0
# 1       19114.12            1824.843333                3.0              4.0
# 2       19114.12            1824.843333                3.0              4.0
#
#    Interest_Rate  Num_of_Loan  \
# 0            3.0          4.0
# 1            3.0          4.0
# 2            3.0          4.0
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# 1  Auto Loan, Credit-Builder Loan, Personal Loan,...                  3.0
# ...

# %%
mydf.shape
# Out:
# (100000, 28)

# %%
mydf.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
mydf.dtypes
# Out:
# ID                            int64
# Customer_ID                   int64
# Month                         int64
# Name                         object
# Age                         float64
# SSN                         float64
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                 float64
# Type_of_Loan                 object
# Delay_from_due_date         float64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# ...

# %%
Annual_Income", "Monthly_Inhand_Salary", 
                   "Num_Bank_Accounts", "Num_Credit_Card", 
                   "Interest_Rate", "Num_of_Loan", 
                   "Delay_from_due_date", "Num_of_Delayed_Payment", 
                   "Credit_Mix", "Outstanding_Debt", 
                   "Credit_History_Age", "Monthly_Balance"
# Out:
#   Cell In[118], line 1
#     Annual_Income", "Monthly_Inhand_Salary",
#                                           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
mydf.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
mydf.duplicated().sum()
# Out:
# 0

# %%
mydf.drop(['ID', 'Customer_ID', 'Name', 'SSN', 'Type_of_Loan'], axis = 1, inplace = True)

mydf.head()
# Out:
#    Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0      1  23.0  Scientist       19114.12            1824.843333
# 1      2  23.0  Scientist       19114.12            1824.843333
# 2      3  23.0  Scientist       19114.12            1824.843333
# 3      4  23.0  Scientist       19114.12            1824.843333
# 4      5  23.0  Scientist       19114.12            1824.843333
#
#    Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                3.0              4.0            3.0          4.0
# 1                3.0              4.0            3.0          4.0
# 2                3.0              4.0            3.0          4.0
# 3                3.0              4.0            3.0          4.0
# 4                3.0              4.0            3.0          4.0
#
#    Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                  3.0                     7.0                 11.27
# ...

# %%
mydf.shape
# Out:
# (100000, 23)

# %%
mydf['Month'] = mydf.Month.astype('O')
mydf['Num_Bank_Accounts'] = mydf.Num_Bank_Accounts.astype('O')
mydf['Num_Credit_Card'] = mydf.Num_Credit_Card.astype('O')
mydf['Num_of_Loan'] = mydf.Num_of_Loan.astype('O')
mydf['Num_Credit_Inquiries'] = mydf.Num_Credit_Inquiries.astype('O')
mydf['Num_of_Delayed_Payment'] = mydf.Num_of_Delayed_Payment.astype('O')

# %%
mydf.dtypes
# Out:
# Month                        object
# Age                         float64
# Occupation                   object
# Annual_Income               float64
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts            object
# Num_Credit_Card              object
# Interest_Rate               float64
# Num_of_Loan                  object
# Delay_from_due_date         float64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries         object
# Credit_Mix                   object
# Outstanding_Debt            float64
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# Monthly_Balance             float64
# Credit_Score                 object
# dtype: object

# %%
mydf.describe()
# Out:
#                  Age  Annual_Income  Monthly_Inhand_Salary  Interest_Rate  \
# count  100000.000000  100000.000000          100000.000000   100000.00000
# mean       33.316340   50505.123449            4197.270835       14.53208
# std        10.764812   38299.422093            3186.432497        8.74133
# min        14.000000    7005.930000             303.645417        1.00000
# 25%        24.000000   19342.972500            1626.594167        7.00000
# 50%        33.000000   36999.705000            3095.905000       13.00000
# 75%        42.000000   71683.470000            5957.715000       20.00000
# max        56.000000  179987.280000           15204.633333       34.00000
#
#        Delay_from_due_date  Changed_Credit_Limit  Outstanding_Debt  \
# count         100000.00000         100000.000000     100000.000000
# mean              21.08141             10.470323       1426.220376
# std               14.80456              6.609481       1155.129026
# ...

# %% [markdown]
# ## The average age of a person having credit card is 33
# ## the average annual_income of a person is 50505.123449

# %%
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Month                     100000 non-null  object
#  1   Age                       100000 non-null  float64
#  2   Occupation                100000 non-null  object
#  3   Annual_Income             100000 non-null  float64
#  4   Monthly_Inhand_Salary     100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  object
#  6   Num_Credit_Card           100000 non-null  object
#  7   Interest_Rate             100000 non-null  float64
#  8   Num_of_Loan               100000 non-null  object
#  9   Delay_from_due_date       100000 non-null  float64
#  10  Num_of_Delayed_Payment    100000 non-null  object
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Num_Credit_Inquiries      100000 non-null  object
# ...

# %%
## finding the number of numerical and categorical features in the given dataset

numeric_cols = [feature for feature in mydf.columns if mydf[feature].dtype != 'O']

categoric_cols = [feature for feature in mydf.columns if mydf[feature].dtype == 'O']

# %%
print('The number of numeric columns are {}'.format(len(numeric_cols)))
print('The number of categoric columns are {}'.format(len(categoric_cols)))
# Out:
# The number of numeric columns are 12
# The number of categoric columns are 11

# %%
numeric_cols = mydf[['Age',
 'Annual_Income',
 'Monthly_Inhand_Salary',
 'Interest_Rate',
 'Delay_from_due_date',
 'Changed_Credit_Limit',
 'Outstanding_Debt',
 'Credit_Utilization_Ratio',
 'Credit_History_Age',
 'Total_EMI_per_month',
 'Amount_invested_monthly',
 'Monthly_Balance']]

numeric_cols.head()
# Out:
#     Age  Annual_Income  Monthly_Inhand_Salary  Interest_Rate  \
# 0  23.0       19114.12            1824.843333            3.0
# 1  23.0       19114.12            1824.843333            3.0
# 2  23.0       19114.12            1824.843333            3.0
# 3  23.0       19114.12            1824.843333            3.0
# 4  23.0       19114.12            1824.843333            3.0
#
#    Delay_from_due_date  Changed_Credit_Limit  Outstanding_Debt  \
# 0                  3.0                 11.27            809.98
# 1                  3.0                 11.27            809.98
# 2                  3.0                 11.27            809.98
# 3                  5.0                  6.27            809.98
# 4                  6.0                 11.27            809.98
#
#    Credit_Utilization_Ratio  Credit_History_Age  Total_EMI_per_month  \
# 0                 26.822620               265.0            49.574949
# 1                 31.944960               266.0            49.574949
# ...

# %%
categoric_cols = mydf[['Month',
 'Occupation',
 'Num_Bank_Accounts',
 'Num_Credit_Card',
 'Num_of_Loan',
 'Num_of_Delayed_Payment',
 'Num_Credit_Inquiries',
 'Credit_Mix',
 'Payment_of_Min_Amount',
 'Payment_Behaviour',
 'Credit_Score']]

categoric_cols.head()
# Out:
#   Month Occupation Num_Bank_Accounts Num_Credit_Card Num_of_Loan  \
# 0     1  Scientist               3.0             4.0         4.0
# 1     2  Scientist               3.0             4.0         4.0
# 2     3  Scientist               3.0             4.0         4.0
# 3     4  Scientist               3.0             4.0         4.0
# 4     5  Scientist               3.0             4.0         4.0
#
#   Num_of_Delayed_Payment Num_Credit_Inquiries Credit_Mix  \
# 0                    7.0                  4.0       Good
# 1                    4.0                  4.0       Good
# 2                    7.0                  4.0       Good
# 3                    4.0                  4.0       Good
# 4                    4.0                  4.0       Good
#
#   Payment_of_Min_Amount                 Payment_Behaviour Credit_Score
# 0                    No   High_spent_Small_value_payments         Good
# 1                    No    Low_spent_Large_value_payments         Good
# ...

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
for i, col in enumerate(numeric_cols.columns):
    plt.subplots(figsize = (15, 7))
    plt.title(f"Data distribution of {col}")
    sns.histplot(data = numeric_cols, x = col, color = 'red', kde = True)

# %%
for i, col in enumerate(numeric_cols.columns):
    plt.subplots(figsize = (15, 7))
    plt.title(f"Data distribution of {col}")
    sns.violinplot(data = numeric_cols, x = col, color = 'green')

# %%
categoric_cols.head(2)
# Out:
#   Month Occupation Num_Bank_Accounts Num_Credit_Card Num_of_Loan  \
# 0     1  Scientist               3.0             4.0         4.0
# 1     2  Scientist               3.0             4.0         4.0
#
#   Num_of_Delayed_Payment Num_Credit_Inquiries Credit_Mix  \
# 0                    7.0                  4.0       Good
# 1                    4.0                  4.0       Good
#
#   Payment_of_Min_Amount                Payment_Behaviour Credit_Score
# 0                    No  High_spent_Small_value_payments         Good
# 1                    No   Low_spent_Large_value_payments         Good

# %%
plt.subplots(4, 2, figsize = (25,15))
plt.suptitle('Distribution of categoric columns')
plt.subplot(421)
plt.title('distribution of occupation')
plt.pie(x = categoric_cols.Occupation.value_counts(), labels=['Lawyer',"Engineer" ,"Architect","Mechanic","Scientist","Accountant","Developer","Media_Manager","Teacher","Entrepreneur","Doctor","Journalist","Manager","Musician", "Writer"], autopct = '%.2f%%')


plt.subplot(422)
plt.title('Number_of_bank_accounts')
plt.pie(x = categoric_cols.Num_Bank_Accounts.value_counts(), labels=['6','7','8','4','5','3','9','10','1','0','2','11'], autopct = '%.2f%%')

plt.subplot(423)
plt.title('Number_of_credit_cards')
plt.pie(x = categoric_cols.Num_Credit_Card.value_counts(), labels=['5','7','6','4','3','8','10','9','2','1','11','0'], autopct = '%.2f%%')

plt.subplot(424)
plt.title('Num_of_Loan')
plt.pie(x = categoric_cols.Num_of_Loan.value_counts(), labels=['3','2','4','0','1','6','7','5','9','8'], autopct = '%.2f%%')


plt.subplot(425)
plt.title('Credit_Mix')
plt.pie(x = categoric_cols.Credit_Mix.value_counts(), labels=['Standard','Good','Bad'], autopct = '%.2f%%')

plt.subplot(426)
plt.title('Payment_of_Min_Amount')
plt.pie(x = categoric_cols.Credit_Mix.value_counts(), labels=['Yes','No','NM'], autopct = '%.2f%%')

plt.subplot(427)
plt.title('Payment_Behaviour')
plt.pie(x = categoric_cols.Payment_Behaviour.value_counts(), labels=["Low_spent_Small_value_payments","High_spent_Medium_value_payments" ,"High_spent_Large_value_payments" ,"Low_spent_Medium_value_payments" ,"High_spent_Small_value_payments" ,"Low_spent_Large_value_payments"], autopct = '%.2f%%')

plt.subplot(428)
plt.title('Credit_Score')
plt.pie(x = categoric_cols.Credit_Score.value_counts(), labels=['Standard', 'Poor', 'Good'], autopct = '%.2f%%')



plt.show()

# %%
for i, col in enumerate(categoric_cols.columns):
    plt.subplots(figsize = (30, 15))
    plt.suptitle('Distribution of categorical columns')
    plt.title(f"Distribution of {col}")
    sns.countplot(data = categoric_cols, x = col)
    plt.show()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
fig, ax = plt.subplots(figsize = (30, 15))
plt.suptitle('Bivariate analysis')

plt.subplot()
plt.title('Occupation Vs Credit_score')
sns.countplot(data = mydf, x = 'Occupation', hue = 'Credit_Score')

plt.show()

# %%
mydf.head(2)
# Out:
#   Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0     1  23.0  Scientist       19114.12            1824.843333
# 1     2  23.0  Scientist       19114.12            1824.843333
#
#   Num_Bank_Accounts Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0               3.0             4.0            3.0         4.0
# 1               3.0             4.0            3.0         4.0
#
#    Delay_from_due_date Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                  3.0                    7.0                 11.27
# 1                  3.0                    4.0                 11.27
#
#   Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 0                  4.0       Good            809.98                  26.82262
# 1                  4.0       Good            809.98                  31.94496
#
#    Credit_History_Age Payment_of_Min_Amount  Total_EMI_per_month  \
# 0               265.0                    No            49.574949
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('Avg_annual_income Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Annual_Income)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgAnnualIncome, labels = ['good', 'standard', 'poor'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## Fig-1 : The highest average annual income of a good credit score is 65203.7
# ## Fig-2 : Most of the people are earning poor avg annual income with 61.23%

# %%
import numpy as np

# %%
good = mydf.query('Annual_Income >= 65203.7')

# %%
good.head(2)
# Out:
#    Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 16     1  34.0   Engineer      143162.64               12187.22
# 17     2  34.0   Engineer      143162.64               12187.22
#
#    Num_Bank_Accounts Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 16               1.0             5.0            8.0         3.0
# 17               1.0             5.0            8.0         3.0
#
#     Delay_from_due_date Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 16                  5.0                    8.0                   7.1
# 17                 13.0                    6.0                   7.1
#
#    Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 16                  3.0       Good           1303.01
# 17                  3.0       Good           1303.01
#
#     Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 16                 28.616735               213.0                    No
# ...

# %%
standard = mydf.query('Annual_Income >=50987.2 and Annual_Income <= 65203.7')

# %%
len(standard)
# Out:
# 9624

# %%
poor = mydf.query('Annual_Income <=50987.2')

# %%
avgAnnualIncome = [len(good), len(standard), len(poor)]

# %%
avgAnnualIncome
# Out:
# [29144, 9624, 61232]

# %%
poor.Annual_Income.max()
# Out:
# 50940.09

# %%
grouped_data = mydf.groupby(by = 'Credit_Score').mean(numeric_only=True)

grouped_data
# Out:
#                     Age  Annual_Income  Monthly_Inhand_Salary  Interest_Rate  \
# Credit_Score
# Good          36.402625   65203.672105            5399.919696       7.662329
# Poor          31.194565   40584.515325            3380.560657      20.187116
# Standard      33.438673   50987.164840            4239.436890      13.751420
#
#               Delay_from_due_date  Changed_Credit_Limit  Outstanding_Debt  \
# Credit_Score
# Good                    10.958997              7.249857        801.256324
# Poor                    29.728809             11.116281       2081.473157
# Standard                19.759431             11.197803       1278.419552
#
#               Credit_Utilization_Ratio  Credit_History_Age  \
# Credit_Score
# Good                         32.686107          284.765650
# Poor                         31.986146          170.061797
# Standard                     32.313820          227.814195
#
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('Avg_monthly_salary Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Monthly_Inhand_Salary)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgMonthlySalary, labels = ['good', 'standard', 'poor'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## The highest average monthly income of a good credit score is 5399.92
# ## Most of the people are having poor credit score with 58.16%

# %%
good_monthly = mydf.query('Monthly_Inhand_Salary >= 5399.92')

# %%
good_monthly.head(2)
# Out:
#    Month   Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 16     1  34.0   Engineer      143162.64               12187.22
# 17     2  34.0   Engineer      143162.64               12187.22
#
#    Num_Bank_Accounts Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 16               1.0             5.0            8.0         3.0
# 17               1.0             5.0            8.0         3.0
#
#     Delay_from_due_date Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 16                  5.0                    8.0                   7.1
# 17                 13.0                    6.0                   7.1
#
#    Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  \
# 16                  3.0       Good           1303.01
# 17                  3.0       Good           1303.01
#
#     Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 16                 28.616735               213.0                    No
# ...

# %%
standard_monthly = mydf.query('Monthly_Inhand_Salary >= 4239.44 and Monthly_Inhand_Salary <= 5399.92')

# %%
poor_monthly = mydf.query('Monthly_Inhand_Salary <= 5399.92')

# %%
avgMonthlySalary = [len(good_monthly), len(standard_monthly), len(poor_monthly)]

# %%
avgMonthlySalary
# Out:
# [29220, 9659, 70780]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('Avg_monthly_interest_rate Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Interest_Rate)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgMonthlyInterestRate, labels = ['good', 'poor', 'standard'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## The people with poor credit score are having highest average interest rate with 20.1871
# ## Most of the people are having good interest rate with 51.13%

# %%
good_Interest_Rate = mydf.query('Interest_Rate <= 13.7514')

# %%
poor_interest_rate = mydf.query('Interest_Rate >=20.1871')

# %%
standard_interest_rate = mydf.query('Interest_Rate >= 13.7514 and Interest_Rate <= 20.1871')

# %%
avgMonthlyInterestRate = [len(good_Interest_Rate), len(poor_interest_rate), len(standard_interest_rate)]

# %%
avgMonthlyInterestRate
# Out:
# [51128, 22936, 25936]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('Avg_Outstanding_Debt Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Outstanding_Debt)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgDebt, labels = ['good', 'poor', 'standard'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## The people with poor credit score are having highest average outstanding debt of 2081.47
# ## most of the people with good credit score are having low outstanding debt with 55.55%

# %%
good_debt = mydf.query('Outstanding_Debt <=1278.42')

# %%
poor_debt = mydf.query('Outstanding_Debt >=2081.47')

# %%
standard_debt = mydf.query('Outstanding_Debt >=1278.42 and Outstanding_Debt<=2081.47')

# %%
avgDebt = [len(good_debt), len(poor_debt), len(standard_debt)]

# %%
avgDebt
# Out:
# [55552, 23008, 21440]

# %%
grouped_data
# Out:
#                     Age  Annual_Income  Monthly_Inhand_Salary  Interest_Rate  \
# Credit_Score
# Good          36.402625   65203.672105            5399.919696       7.662329
# Poor          31.194565   40584.515325            3380.560657      20.187116
# Standard      33.438673   50987.164840            4239.436890      13.751420
#
#               Delay_from_due_date  Changed_Credit_Limit  Outstanding_Debt  \
# Credit_Score
# Good                    10.958997              7.249857        801.256324
# Poor                    29.728809             11.116281       2081.473157
# Standard                19.759431             11.197803       1278.419552
#
#               Credit_Utilization_Ratio  Credit_History_Age  \
# Credit_Score
# Good                         32.686107          284.765650
# Poor                         31.986146          170.061797
# Standard                     32.313820          227.814195
#
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('avg_Total_EMI_per_month Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Total_EMI_per_month)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgMonthlyEmi, labels = ['good', 'poor', 'standard'], autopct = '%.2f%%')

plt.show()

# %% [markdown]
# ## The people with good credit score are having an average of monthly EMI is 121.691
# ## Most of the people with standard credit score are maximum with avg monthly EMI 51.55%

# %%
good_emi = mydf.query('Total_EMI_per_month >=121.691')
poor_emi = mydf.query('Total_EMI_per_month >=111.198 <= 121.691')
standard_emi = mydf.query('Total_EMI_per_month<=111.198')

# %%
avgMonthlyEmi = [len(good_emi), len(poor_emi),len(standard_emi)]

# %%
avgMonthlyEmi
# Out:
# [30310, 32820, 67180]

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
plt.subplot(121)
plt.suptitle('avg_Amount_invested_monthly Vs Credit_score')
sns.barplot(data = grouped_data, x= grouped_data.index, y = grouped_data.Amount_invested_monthly)
for container in ax[0].containers:
    ax[0].bar_label(container, color = 'black', size = 10)

plt.subplot(122)
plt.pie(x = avgMonthlyInvest, labels = ['good', 'poor', 'standard'], autopct = '%.2f%%')

plt.show()

# %%
good_invest = mydf.query('Amount_invested_monthly >= 67.4176')
poor_invest = mydf.query('Amount_invested_monthly <= 55.3719')
standard_invest = mydf.query('Amount_invested_monthly >= 55.3719 and Amount_invested_monthly <=67.4176')

# %%
avgMonthlyInvest = [len(good_invest), len(poor_invest), len(standard_invest)]

# %%
avgMonthlyInvest
# Out:
# [27880, 61896, 10224]
